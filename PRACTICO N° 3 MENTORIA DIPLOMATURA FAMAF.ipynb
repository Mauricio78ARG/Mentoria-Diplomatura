# %%
##PRACTICO 3 MENTORIA: APLICAR MODELOS PREDICTIVOS SOBRE CATEGORIAS DE USUARIOS DEL TRASNPORTE URBANO PARA MAYO 2022##
import pandas as pd 
df=pd.read_csv(r"D:\Documentos Mauricio\Desktop\Diplomatura FAMAF2022\Mentoría_Sistema de Transporte Urbano\Practico 3\base_mayo22_habil.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8430650 entries, 0 to 8430649
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   LINEA     object
#  1   SENTIDO   object
#  2   FECHA     object
#  3   TARJETA   int64
#  4   CONTRATO  object
# dtypes: int64(1), object(4)
# memory usage: 321.6+ MB

# %%
df.head()
# LA BASE ESTA A NIVEL DE VIAJES POR TARJETA#
# Out:
#    LINEA SENTIDO                   FECHA  TARJETA       CONTRATO
# 0  L42 E     Ida  02/05/2022 04:36:14 PM  1000001  Usuario comun
# 1  L35 T     Ida  02/05/2022 10:22:27 PM  1000002  Usuario comun
# 2      C     Ida  02/05/2022 03:20:12 PM  1000003  Usuario comun
# 3      C  Vuelta  02/05/2022 09:18:06 AM  1000003  Usuario comun
# 4      C     Ida  02/05/2022 06:56:40 AM  1000004  Usuario comun

# %%
##1-INGENIERÍA DE CARACTERÍSTICAS##

# %%
import datetime as dt

# %%
# VARIABLE FECHA DE STRING A DATETIME##
df['Fecha2'] = pd.to_datetime(df['FECHA'], format='%d/%m/%Y %I:%M:%S %p')

# %%
df
# Out:
#          LINEA SENTIDO                   FECHA  TARJETA       CONTRATO  \
# 0        L42 E     Ida  02/05/2022 04:36:14 PM  1000001  Usuario comun
# 1        L35 T     Ida  02/05/2022 10:22:27 PM  1000002  Usuario comun
# 2            C     Ida  02/05/2022 03:20:12 PM  1000003  Usuario comun
# 3            C  Vuelta  02/05/2022 09:18:06 AM  1000003  Usuario comun
# 4            C     Ida  02/05/2022 06:56:40 AM  1000004  Usuario comun
# ...        ...     ...                     ...      ...            ...
# 8430645  L80 T  Vuelta  31/05/2022 09:38:23 AM  1237215  Usuario comun
# 8430646  L36 T     Ida  31/05/2022 02:39:28 PM  1677773  Usuario comun
# 8430647    L25  Vuelta  31/05/2022 07:16:06 PM  1237216  Usuario comun
# 8430648    L10     Ida  31/05/2022 02:00:10 PM  1237218  Usuario comun
# 8430649  L32 T  Vuelta  31/05/2022 08:38:08 PM  1595584  Usuario comun
#
#                      Fecha2
# 0       2022-05-02 16:36:14
# 1       2022-05-02 22:22:27
# 2       2022-05-02 15:20:12
# 3       2022-05-02 09:18:06
# 4       2022-05-02 06:56:40
# ...                     ...
# 8430645 2022-05-31 09:38:23
# 8430646 2022-05-31 14:39:28
# 8430647 2022-05-31 19:16:06
# 8430648 2022-05-31 14:00:10
# 8430649 2022-05-31 20:38:08
#
# [8430650 rows x 6 columns]

# %%
## OBTENEMOS DIA DEL MES EN NOMBRE Y NUMERO##
df['dia_semana']=df['Fecha2'].dt.day_name()
df['dia_numero']= df.Fecha2.dt.strftime('%d')

# %%
df.head(3)
# Out:
#    LINEA SENTIDO                   FECHA  TARJETA       CONTRATO  \
# 0  L42 E     Ida  02/05/2022 04:36:14 PM  1000001  Usuario comun
# 1  L35 T     Ida  02/05/2022 10:22:27 PM  1000002  Usuario comun
# 2      C     Ida  02/05/2022 03:20:12 PM  1000003  Usuario comun
#
#                Fecha2 dia_semana dia_numero
# 0 2022-05-02 16:36:14     Monday         02
# 1 2022-05-02 22:22:27     Monday         02
# 2 2022-05-02 15:20:12     Monday         02

# %%
## NO OLVIDAR QUE CADA FILA TIENE QUE SER UNA TARJETA POR LO QUE HAY QUE SUMARIZAR A NIVEL TARJETA, LAS VARIABLES QUE SE DECIDAN UTILZAR##

# %%
## NO OLVIDAR ANTES DE COLAPSAR LA BASE A UNA FILA UNA TARJETA, OBTENER DUMMIES DE SENTIDO, LINEA, DIA MES , DIA SEMANA, HORA, ETC Y RECIEN AHI HACER CONTEO POR TARJETA Y COLAPSAR BASE
